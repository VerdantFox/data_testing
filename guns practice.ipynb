# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
census = pd.read_csv('acs2015_county_data.csv', encoding='latin-1')

# %%
census.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
# 3     0.4      ...        0.6          1.5         0.7         28.8      8294
# 4     0.3      ...        0.9          0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         73.6        20.9           5.5         0.0           7.6
# 1         81.5        12.3           5.8         0.4           7.5
# 2         71.8        20.8           7.3         0.1          17.6
# 3         76.8        16.1           6.7         0.4           8.3
# 4         82.0        13.5           4.2         0.4           7.7
#
# [5 rows x 37 columns]

# %%
cities = pd.read_csv('uscitiesv1.4.csv')

# %%
cities.head()
# Out:
#              city      city_ascii state_id  state_name  county_fips  \
# 0   Prairie Ridge   Prairie Ridge       WA  Washington        53053
# 1          Edison          Edison       WA  Washington        53057
# 2        Packwood        Packwood       WA  Washington        53041
# 3  Wautauga Beach  Wautauga Beach       WA  Washington        53035
# 4          Harper          Harper       WA  Washington        53035
#
#   county_name      lat       lng  population  population_proper  density  \
# 0      Pierce  47.1443 -122.1408         NaN                NaN   1349.8
# 1      Skagit  48.5602 -122.4311         NaN                NaN    127.4
# 2       Lewis  46.6085 -121.6702         NaN                NaN    213.9
# 3      Kitsap  47.5862 -122.5482         NaN                NaN    261.7
# 4      Kitsap  47.5207 -122.5196         NaN                NaN    342.1
#
#     source  incorporated             timezone         zips          id
# 0  polygon         False  America/Los_Angeles  98360 98391  1840037882
# 1  polygon         False  America/Los_Angeles        98232  1840017314
# 2  polygon         False  America/Los_Angeles        98361  1840025265
# 3    point         False  America/Los_Angeles        98366  1840037725
# 4    point         False  America/Los_Angeles        98366  1840037659

# %%
cities.columns
# Out:
# Index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#        'county_name', 'lat', 'lng', 'population', 'population_proper',
#        'density', 'source', 'incorporated', 'timezone', 'zips', 'id'],
#       dtype='object')

# %%
cities.drop(['population', 'population_proper', 'incorporated', 'id', 
             'source', 'city_ascii', 'timezone', 'lat', 'lng', 'county_fips',],
            axis=1, inplace=True)

# %%
cities.head()
# Out:
#              city state_id  state_name county_name  density         zips
# 0   Prairie Ridge       WA  Washington      Pierce   1349.8  98360 98391
# 1          Edison       WA  Washington      Skagit    127.4        98232
# 2        Packwood       WA  Washington       Lewis    213.9        98361
# 3  Wautauga Beach       WA  Washington      Kitsap    261.7        98366
# 4          Harper       WA  Washington      Kitsap    342.1        98366

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36650 entries, 0 to 36649
# Data columns (total 6 columns):
# city           36650 non-null object
# state_id       36650 non-null object
# state_name     36650 non-null object
# county_name    36650 non-null object
# density        36650 non-null float64
# zips           36649 non-null object
# dtypes: float64(1), object(5)
# memory usage: 1.7+ MB

# %%
cities.at['zips', 17911] = 99584

# %%
cities[cities['zips'].apply(func=typecheck)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d4ffc0e628c5> in <module>()
# ----> 1 cities[cities['zips'].apply(func=typecheck)]
#
# NameError: name 'typecheck' is not defined

# %%
def firstzip(x):
    if type(x) == str:
        return x.split()[0]

# %%
cities['zips'] = cities['zips'].apply(firstzip)

# %%
cities.head()
# Out:
#              city state_id  state_name county_name  density   zips  17911
# 0   Prairie Ridge       WA  Washington      Pierce   1349.8  98360    NaN
# 1          Edison       WA  Washington      Skagit    127.4  98232    NaN
# 2        Packwood       WA  Washington       Lewis    213.9  98361    NaN
# 3  Wautauga Beach       WA  Washington      Kitsap    261.7  98366    NaN
# 4          Harper       WA  Washington      Kitsap    342.1  98366    NaN

# %%
cities.drop(17911, axis=1, inplace=True)

# %%
cities.head()
# Out:
#              city state_id  state_name county_name  density   zips
# 0   Prairie Ridge       WA  Washington      Pierce   1349.8  98360
# 1          Edison       WA  Washington      Skagit    127.4  98232
# 2        Packwood       WA  Washington       Lewis    213.9  98361
# 3  Wautauga Beach       WA  Washington      Kitsap    261.7  98366
# 4          Harper       WA  Washington      Kitsap    342.1  98366

# %%
census = pd.read_csv('acs2015_county_data.csv')

# %%
census.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
# 3     0.4      ...        0.6          1.5         0.7         28.8      8294
# 4     0.3      ...        0.9          0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         73.6        20.9           5.5         0.0           7.6
# 1         81.5        12.3           5.8         0.4           7.5
# 2         71.8        20.8           7.3         0.1          17.6
# 3         76.8        16.1           6.7         0.4           8.3
# 4         82.0        13.5           4.2         0.4           7.7
#
# [5 rows x 37 columns]

# %%
guns = pd.read_csv('gun-violence-data_01-2013_03-2018.csv')

# %%
guns.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# 3  http://www.gunviolencearchive.org/incident/478925
# 4  http://www.gunviolencearchive.org/incident/478959
#
#                                           source_url  \
# 0  http://www.post-gazette.com/local/south/2013/0...
# 1  http://www.dailybulletin.com/article/zz/201301...
# 2  http://chronicle.northcoastnow.com/2013/02/14/...
# 3  http://www.dailydemocrat.com/20130106/aurora-s...
# 4  http://www.journalnow.com/news/local/article_d...
#
#    incident_url_fields_missing          ...           \
# 0                        False          ...
# 1                        False          ...
# 2                        False          ...
# 3                        False          ...
# 4                        False          ...
#
#                      participant_age  \
# 0                              0::20
# 1                              0::20
# 2  0::25||1::31||2::33||3::34||4::33
# 3         0::29||1::33||2::56||3::33
# 4         0::18||1::46||2::14||3::47
#
#                                participant_age_group  \
# 0  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 1  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 3  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 4  0::Adult 18+||1::Adult 18+||2::Teen 12-17||3::...
#
#                             participant_gender  \
# 0         0::Male||1::Male||3::Male||4::Female
# 1                                      0::Male
# 2  0::Male||1::Male||2::Male||3::Male||4::Male
# 3         0::Female||1::Male||2::Male||3::Male
# 4       0::Female||1::Male||2::Male||3::Female
#
#                                     participant_name  \
# 0                                     0::Julian Sims
# 1                                  0::Bernard Gillis
# 2  0::Damien Bell||1::Desmen Noble||2::Herman Sea...
# 3  0::Stacie Philbrook||1::Christopher Ratliffe||...
# 4  0::Danielle Imani Jameison||1::Maurice Eugene ...
#
#    participant_relationship  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                 3::Family
#
#                                   participant_status  \
# 0  0::Arrested||1::Injured||2::Injured||3::Injure...
# 1      0::Killed||1::Injured||2::Injured||3::Injured
# 2  0::Injured, Unharmed, Arrested||1::Unharmed, A...
# 3         0::Killed||1::Killed||2::Killed||3::Killed
# 4       0::Injured||1::Injured||2::Killed||3::Killed
#
#                                     participant_type  \
# 0  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 1  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2  0::Subject-Suspect||1::Subject-Suspect||2::Vic...
# 3  0::Victim||1::Victim||2::Victim||3::Subject-Su...
# 4  0::Victim||1::Victim||2::Victim||3::Subject-Su...
#
#                                              sources state_house_district  \
# 0  http://pittsburgh.cbslocal.com/2013/01/01/4-pe...                  NaN
# 1  http://losangeles.cbslocal.com/2013/01/01/man-...                 62.0
# 2  http://www.morningjournal.com/general-news/201...                 56.0
# 3  http://denver.cbslocal.com/2013/01/06/officer-...                 40.0
# 4  http://myfox8.com/2013/01/08/update-mother-sho...                 62.0
#
#   state_senate_district
# 0                   NaN
# 1                  35.0
# 2                  13.0
# 3                  28.0
# 4                  27.0
#
# [5 rows x 29 columns]

# %%
guns.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
guns.drop(axis=1, inplace=True, 
          labels=['incident_id', 'address', 'incident_url', 'source_url',
                  'incident_url_fields_missing', 'congressional_district', 'gun_stolen', 
                  'gun_type', 'location_description', 'n_guns_involved', 'notes', 
                  'participant_age', 'participant_age_group', 'participant_gender', 
                  'participant_name', 'participant_relationship', 'participant_status', 
                  'participant_type', 'sources', 'state_house_district',  'state_senate_district',])

# %%
guns.head()
# Out:
#          date           state city_or_county  n_killed  n_injured  \
# 0  2013-01-01    Pennsylvania     Mckeesport         0          4
# 1  2013-01-01      California      Hawthorne         1          3
# 2  2013-01-01            Ohio         Lorain         1          3
# 3  2013-01-05        Colorado         Aurora         4          0
# 4  2013-01-07  North Carolina     Greensboro         2          2
#
#                             incident_characteristics  latitude  longitude
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3  Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4  Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569

# %%
guns.columns
# Out:
# Index(['date', 'state', 'city_or_county', 'n_killed', 'n_injured',
#        'incident_characteristics', 'latitude', 'longitude'],
#       dtype='object')

# %%
guns.columns = ['date', 'state_name', 'city', 'n_killed', 'n_injured',
       'incident_characteristics', 'latitude', 'longitude']

# %%
guns.columns
# Out:
# Index(['date', 'state_name', 'city', 'n_killed', 'n_injured',
#        'incident_characteristics', 'latitude', 'longitude'],
#       dtype='object')

# %%
guns.head()
# Out:
#          date      state_name        city  n_killed  n_injured  \
# 0  2013-01-01    Pennsylvania  Mckeesport         0          4
# 1  2013-01-01      California   Hawthorne         1          3
# 2  2013-01-01            Ohio      Lorain         1          3
# 3  2013-01-05        Colorado      Aurora         4          0
# 4  2013-01-07  North Carolina  Greensboro         2          2
#
#                             incident_characteristics  latitude  longitude
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3  Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4  Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569

# %%
guns['city'].head()
# Out:
# 0    Mckeesport
# 1     Hawthorne
# 2        Lorain
# 3        Aurora
# 4    Greensboro
# Name: city, dtype: object

# %%
# guns['city'] = guns['city'].apply(lambda x: x.split()[0])

# %%
cities.head()
# Out:
#              city state_id  state_name county_name  density   zips
# 0   Prairie Ridge       WA  Washington      Pierce   1349.8  98360
# 1          Edison       WA  Washington      Skagit    127.4  98232
# 2        Packwood       WA  Washington       Lewis    213.9  98361
# 3  Wautauga Beach       WA  Washington      Kitsap    261.7  98366
# 4          Harper       WA  Washington      Kitsap    342.1  98366

# %%
gunscounties = guns.merge(right=cities, how='left', on=['city', 'state_name'], validate='many_to_one')

# %%
gunscounties.head()
# Out:
#          date      state_name        city  n_killed  n_injured  \
# 0  2013-01-01    Pennsylvania  Mckeesport         0          4
# 1  2013-01-01      California   Hawthorne         1          3
# 2  2013-01-01            Ohio      Lorain         1          3
# 3  2013-01-05        Colorado      Aurora         4          0
# 4  2013-01-07  North Carolina  Greensboro         2          2
#
#                             incident_characteristics  latitude  longitude  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3  Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4  Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569
#
#   state_id  county_name  density   zips
# 0      NaN          NaN      NaN    NaN
# 1       CA  Los Angeles   5589.0  90250
# 2       OH       Lorain   1039.0  44052
# 3       CO        Adams    909.0  80247
# 4       NC     Guilford    874.0  27410

# %%
gunscounties.to_csv('guns_cities.csv', index=False)

# %%
guns = pd.read_csv('guns_cities.csv')

# %%
guns.head()
# Out:
#          date      state_name        city  n_killed  n_injured  \
# 0  2013-01-01    Pennsylvania  Mckeesport         0          4
# 1  2013-01-01      California   Hawthorne         1          3
# 2  2013-01-01            Ohio      Lorain         1          3
# 3  2013-01-05        Colorado      Aurora         4          0
# 4  2013-01-07  North Carolina  Greensboro         2          2
#
#                             incident_characteristics  latitude  longitude  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3  Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4  Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569
#
#   state_id  county_name  density     zips
# 0      NaN          NaN      NaN      NaN
# 1       CA  Los Angeles   5589.0  90250.0
# 2       OH       Lorain   1039.0  44052.0
# 3       CO        Adams    909.0  80247.0
# 4       NC     Guilford    874.0  27410.0

# %%
guns['zips'][0]
# Out:
# nan

# %%
guns['county_name'][0]
# Out:
# nan

# %%
type(guns['county_name'][0])
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
guns[guns['county_name'].isnull()]
# Out:
#               date            state_name  \
# 0       2013-01-01          Pennsylvania
# 16      2013-02-03            California
# 22      2013-02-19            California
# 29      2013-03-03              Michigan
# 44      2013-03-30            California
# 47      2013-04-07              New York
# 55      2013-04-22              Illinois
# 78      2013-05-18              New York
# 94      2013-06-02               Georgia
# 140     2013-07-13            New Jersey
# 141     2013-07-14              Michigan
# 162     2013-08-06            New Jersey
# 194     2013-09-16  District of Columbia
# 220     2013-10-13          Pennsylvania
# 224     2013-10-21          Pennsylvania
# 232     2013-10-29        South Carolina
# 239     2013-11-09                 Texas
# 263     2013-12-15               Florida
# 269     2013-12-25            New Jersey
# 286     2014-01-01               Georgia
# 287     2014-01-01              Virginia
# 304     2014-01-01              Colorado
# 320     2014-01-01               Alabama
# 322     2014-01-01                Hawaii
# 343     2014-01-01        North Carolina
# 363     2014-01-01            New Jersey
# 364     2014-01-01            New Jersey
# 365     2014-01-01            New Jersey
# 370     2014-01-01           Mississippi
# 382     2014-01-01              Oklahoma
# ...            ...                   ...
# 239153  2018-03-28               Wyoming
# 239170  2018-03-28                Kansas
# 239194  2018-03-28             Tennessee
# 239204  2018-03-28              Michigan
# 239218  2018-03-28             Wisconsin
# 239226  2018-03-28               Georgia
# 239250  2018-03-28              Maryland
# 239277  2018-03-28               Vermont
# 239314  2018-03-29                 Texas
# 239335  2018-03-29                  Utah
# 239363  2018-03-29             Tennessee
# 239378  2018-03-29            California
# 239391  2018-03-29               Georgia
# 239400  2018-03-29                Oregon
# 239411  2018-03-29               Florida
# 239453  2018-03-30               Indiana
# 239455  2018-03-30        North Carolina
# 239458  2018-03-30              Oklahoma
# 239473  2018-03-30              New York
# 239512  2018-03-30            California
# 239515  2018-03-30              Arkansas
# 239536  2018-03-30               Florida
# 239543  2018-03-30              Missouri
# 239544  2018-03-30              Colorado
# 239564  2018-03-31               Georgia
# 239579  2018-03-31              Illinois
# 239591  2018-03-31              Virginia
# 239625  2018-03-31              Maryland
# 239644  2018-03-31              New York
# 239671  2018-03-31            Washington
#
#                                            city  n_killed  n_injured  \
# 0                                    Mckeesport         0          4
# 16                                Yuba (county)         1          3
# 22                              Orange (county)         4          3
# 29                             Saginaw (county)         0          4
# 44                              Merced (county)         3          2
# 47                         New York (Manhattan)         1          3
# 55                          Chicago (Englewood)         0          4
# 78                                      Jamaica         1          0
# 94                                     Lagrange         0          7
# 140                 Trenton (Hamilton Township)         1          4
# 141                     Grand Rapids (Kentwood)         0          5
# 162                                   Montclair         0          4
# 194                        Washington Navy Yard        11          3
# 220                                Wilkes Barre         1          0
# 224                       Pittsburgh (Homewood)         2          5
# 232                          Bradley (Callison)         5          0
# 239                                     Cypress         2         16
# 263                    Homestead (Florida City)         1          3
# 269                                   Irvington         3          2
# 286                                 Bibb County         0          1
# 287                       Prince William County         0          1
# 304                                  Canon City         0          1
# 320                                    Crenshaw         1          0
# 322                                       Lihue         1          0
# 343                               Duplin County         0          1
# 363                         Gloucester Township         0          0
# 364                                Mount Laurel         0          2
# 365                                  Belleville         0          0
# 370                                    Franklin         0          0
# 382                             Okmulgee County         0          2
# ...                                         ...       ...        ...
# 239153                   Jackson (Jackson Hole)         0          0
# 239170                      Wichita (Park City)         0          0
# 239194                                Hermitage         1          0
# 239204                              South Shore         0          1
# 239218                    Milwaukee (Wauwatosa)         0          0
# 239226                                 Lagrange         0          0
# 239250                   Upper Marlboro (Largo)         1          0
# 239277               Bellows Falls (Rockingham)         0          1
# 239314                                   Adkins         1          0
# 239335                  Salt Lake City (Murray)         2          0
# 239363                                  Madison         0          1
# 239378                                  Tujunga         0          1
# 239391                           Troup (county)         0          1
# 239400                         Cowlitz (county)         0          0
# 239411                 Homestead (Florida City)         0          1
# 239453                  Indianapolis (Lawrence)         1          0
# 239455            Winston Salem (Winston-salem)         1          0
# 239458                 Oklahoma City (Del City)         0          1
# 239473                          Corona (Queens)         0          1
# 239512                            Granada Hills         0          0
# 239515  Hot Springs National Park (Hot Springs)         0          0
# 239536             Fort Lauderdale (Lauderhill)         0          1
# 239543                     Chaffee (Allenville)         1          0
# 239544                               Canon City         2          0
# 239564                       Chattooga (county)         0          1
# 239579                                   Dekalb         1          0
# 239591                                  St Paul         0          1
# 239625          Capitol Heights (Seat Pleasant)         0          0
# 239644                      Spencerport (Ogden)         0          1
# 239671                 Spokane (Spokane Valley)         0          0
#
#                                  incident_characteristics  latitude  \
# 0       Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467
# 16      Shot - Wounded/Injured||Shot - Dead (murder, a...   39.1236
# 22      Shot - Wounded/Injured||Shot - Dead (murder, a...   33.8031
# 29      Shot - Wounded/Injured||Mass Shooting (4+ vict...   43.3944
# 44      Shot - Wounded/Injured||Shot - Dead (murder, a...   37.3603
# 47      Shot - Wounded/Injured||Shot - Dead (murder, a...   40.9018
# 55      Shot - Wounded/Injured||Mass Shooting (4+ vict...   41.7906
# 78      Shot - Dead (murder, accidental, suicide)||Gan...   40.6730
# 94      Shot - Wounded/Injured||Mass Shooting (4+ vict...   33.0354
# 140     Shot - Wounded/Injured||Shot - Dead (murder, a...   40.1981
# 141     Shot - Wounded/Injured||Mass Shooting (4+ vict...   42.8740
# 162     Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.8057
# 194     Shot - Wounded/Injured||Shot - Dead (murder, a...   38.8730
# 220     Shot - Dead (murder, accidental, suicide)||Ins...   41.2350
# 224     Shot - Wounded/Injured||Shot - Dead (murder, a...   40.4555
# 232     Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9881
# 239     Shot - Wounded/Injured||Shot - Dead (murder, a...   29.8840
# 263     Shot - Wounded/Injured||Shot - Dead (murder, a...   25.4631
# 269     Shot - Wounded/Injured||Shot - Dead (murder, a...   40.7217
# 286                                Shot - Wounded/Injured   32.7866
# 287                                Shot - Wounded/Injured   38.7765
# 304     Shot - Wounded/Injured||Officer Involved Incid...   38.4340
# 320             Shot - Dead (murder, accidental, suicide)   31.7839
# 322             Shot - Dead (murder, accidental, suicide)   21.9986
# 343                                Shot - Wounded/Injured   34.9624
# 363     Armed robbery with injury/death and/or evidenc...   39.8258
# 364     Armed robbery with injury/death and/or evidenc...   39.9168
# 365     Armed robbery with injury/death and/or evidenc...   40.7951
# 370     Shots Fired - No Injuries||Officer Involved In...   33.0363
# 382     Shot - Wounded/Injured||Possession of gun by f...   35.5711
# ...                                                   ...       ...
# 239153    Non-Shooting Incident||Gun(s) stolen from owner   43.4757
# 239170  Institution/Group/Business||Non-Shooting Incid...   37.7965
# 239194  Shot - Dead (murder, accidental, suicide)||Hom...   36.1995
# 239204                             Shot - Wounded/Injured       NaN
# 239218                          Shots Fired - No Injuries   43.0607
# 239226  Institution/Group/Business||Non-Shooting Incid...   32.9649
# 239250          Shot - Dead (murder, accidental, suicide)   38.8822
# 239277  Non-Shooting Incident||Domestic Violence||Pist...       NaN
# 239314  Shot - Dead (murder, accidental, suicide)||Bar...   29.3713
# 239335  Shot - Dead (murder, accidental, suicide)||Sui...   40.6871
# 239363                             Shot - Wounded/Injured   36.2663
# 239378          Shot - Wounded/Injured||Domestic Violence   34.2639
# 239391                             Shot - Wounded/Injured   33.0410
# 239400  Shots Fired - No Injuries||Road rage||ATF/LE C...       NaN
# 239411  Shot - Wounded/Injured||Officer Involved Incid...       NaN
# 239453          Shot - Dead (murder, accidental, suicide)   39.8411
# 239455  Shot - Dead (murder, accidental, suicide)||Off...       NaN
# 239458  Shot - Wounded/Injured||Non-Aggression Inciden...   35.3342
# 239473  Shot - Wounded/Injured||Defensive Use||Defensi...       NaN
# 239512  Non-Shooting Incident||Officer Involved Incide...   34.2841
# 239515  Shots Fired - No Injuries||Possession of gun b...   34.4928
# 239536  Shot - Wounded/Injured||Institution/Group/Busi...   26.1362
# 239543  Shot - Dead (murder, accidental, suicide)||Dom...   37.1776
# 239544  Shot - Dead (murder, accidental, suicide)||Sui...   38.4651
# 239564  Shot - Wounded/Injured||Defensive Use||Defensi...   34.5426
# 239579                Shot - Wounded/Injured||House party       NaN
# 239591          Shot - Dead (murder, accidental, suicide)       NaN
# 239625  Shots Fired - No Injuries||Officer Involved In...       NaN
# 239644  Shot - Wounded/Injured||Non-Aggression Inciden...       NaN
# 239671  Non-Shooting Incident||Possession (gun(s) foun...   47.6638
#
#         longitude state_id county_name  density  zips
# 0        -79.8559      NaN         NaN      NaN   NaN
# 16      -121.5830      NaN         NaN      NaN   NaN
# 22      -117.9430      NaN         NaN      NaN   NaN
# 29       -83.9082      NaN         NaN      NaN   NaN
# 44      -120.6540      NaN         NaN      NaN   NaN
# 47       -73.8511      NaN         NaN      NaN   NaN
# 55       -87.6418      NaN         NaN      NaN   NaN
# 78       -73.7881      NaN         NaN      NaN   NaN
# 94       -85.0244      NaN         NaN      NaN   NaN
# 140      -74.7491      NaN         NaN      NaN   NaN
# 141      -85.6052      NaN         NaN      NaN   NaN
# 162      -74.2128      NaN         NaN      NaN   NaN
# 194      -76.9977      NaN         NaN      NaN   NaN
# 220      -75.9011      NaN         NaN      NaN   NaN
# 224      -79.8970      NaN         NaN      NaN   NaN
# 232      -82.2888      NaN         NaN      NaN   NaN
# 239      -95.7187      NaN         NaN      NaN   NaN
# 263      -80.4572      NaN         NaN      NaN   NaN
# 269      -74.2217      NaN         NaN      NaN   NaN
# 286      -83.7199      NaN         NaN      NaN   NaN
# 287      -77.4996      NaN         NaN      NaN   NaN
# 304     -105.2640      NaN         NaN      NaN   NaN
# 320      -86.1926      NaN         NaN      NaN   NaN
# 322     -159.3560      NaN         NaN      NaN   NaN
# 343      -77.9622      NaN         NaN      NaN   NaN
# 363      -75.0659      NaN         NaN      NaN   NaN
# 364      -74.9485      NaN         NaN      NaN   NaN
# 365      -74.1562      NaN         NaN      NaN   NaN
# 370      -90.0028      NaN         NaN      NaN   NaN
# 382      -96.0152      NaN         NaN      NaN   NaN
# ...           ...      ...         ...      ...   ...
# 239153  -110.7700      NaN         NaN      NaN   NaN
# 239170   -97.3360      NaN         NaN      NaN   NaN
# 239194   -86.5994      NaN         NaN      NaN   NaN
# 239204        NaN      NaN         NaN      NaN   NaN
# 239218   -87.9909      NaN         NaN      NaN   NaN
# 239226   -85.1256      NaN         NaN      NaN   NaN
# 239250   -76.8303      NaN         NaN      NaN   NaN
# 239277        NaN      NaN         NaN      NaN   NaN
# 239314   -98.2684      NaN         NaN      NaN   NaN
# 239335  -111.9010      NaN         NaN      NaN   NaN
# 239363   -86.6869      NaN         NaN      NaN   NaN
# 239378  -118.2970      NaN         NaN      NaN   NaN
# 239391   -84.9708      NaN         NaN      NaN   NaN
# 239400        NaN      NaN         NaN      NaN   NaN
# 239411        NaN      NaN         NaN      NaN   NaN
# 239453   -86.0354      NaN         NaN      NaN   NaN
# 239455        NaN      NaN         NaN      NaN   NaN
# 239458   -97.4413      NaN         NaN      NaN   NaN
# 239473        NaN      NaN         NaN      NaN   NaN
# 239512  -118.5110      NaN         NaN      NaN   NaN
# 239515   -93.0583      NaN         NaN      NaN   NaN
# 239536   -80.1865      NaN         NaN      NaN   NaN
# 239543   -89.6703      NaN         NaN      NaN   NaN
# 239544  -105.3090      NaN         NaN      NaN   NaN
# 239564   -85.4508      NaN         NaN      NaN   NaN
# 239579        NaN      NaN         NaN      NaN   NaN
# 239591        NaN      NaN         NaN      NaN   NaN
# 239625        NaN      NaN         NaN      NaN   NaN
# 239644        NaN      NaN         NaN      NaN   NaN
# 239671  -117.2350      NaN         NaN      NaN   NaN
#
# [20723 rows x 12 columns]

# %%
guns['city'][16]
# Out:
# 'Yuba (county)'

# %%
guns.isnull().sum()
# Out:
# date                            0
# state_name                      0
# city                            0
# n_killed                        0
# n_injured                       0
# incident_characteristics      326
# latitude                     7923
# longitude                    7923
# state_id                    20723
# county_name                 20723
# density                     20723
# zips                        20723
# dtype: int64

# %%
guns.head()
# Out:
#          date      state_name        city  n_killed  n_injured  \
# 0  2013-01-01    Pennsylvania  Mckeesport         0          4
# 1  2013-01-01      California   Hawthorne         1          3
# 2  2013-01-01            Ohio      Lorain         1          3
# 3  2013-01-05        Colorado      Aurora         4          0
# 4  2013-01-07  North Carolina  Greensboro         2          2
#
#                             incident_characteristics  latitude  longitude  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3  Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4  Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569
#
#   state_id  county_name  density     zips
# 0      NaN          NaN      NaN      NaN
# 1       CA  Los Angeles   5589.0  90250.0
# 2       OH       Lorain   1039.0  44052.0
# 3       CO        Adams    909.0  80247.0
# 4       NC     Guilford    874.0  27410.0

# %%
guns.head()
# Out:
#          date      state_name        city  n_killed  n_injured  \
# 0  2013-01-01    Pennsylvania  Mckeesport         0          4
# 1  2013-01-01      California   Hawthorne         1          3
# 2  2013-01-01            Ohio      Lorain         1          3
# 3  2013-01-05        Colorado      Aurora         4          0
# 4  2013-01-07  North Carolina  Greensboro         2          2
#
#                             incident_characteristics  latitude  longitude  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3  Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4  Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569
#
#   state_id  county_name  density     zips
# 0      NaN          NaN      NaN      NaN
# 1       CA  Los Angeles   5589.0  90250.0
# 2       OH       Lorain   1039.0  44052.0
# 3       CO        Adams    909.0  80247.0
# 4       NC     Guilford    874.0  27410.0
